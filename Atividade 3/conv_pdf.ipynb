# %% [markdown]
# ## Instalando pacotes necessários

# %% [markdown]
# !apt-get update
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc --break-system-packages

# %%
# !pwd
# !ls
# Out:
# /home/arthur/Documentos/Github/Redes-Neurais/Atividade 3
# Atividade-Pratica-3.ipynb  cifar-10-batches-py	conv_pdf.ipynb

# %% [markdown]
# ## Realizando a conversão para PDF (pode ser necessário ajustar o nome do *notebook*)

# %%
# !jupyter nbconvert --to PDF "Atividade-Pratica-3.ipynb"
# Out:
# [NbConvertApp] Converting notebook Atividade-Pratica-3.ipynb to PDF
# [NbConvertApp] Support files will be in Atividade-Pratica-3_files/
# [NbConvertApp] Making directory ./Atividade-Pratica-3_files
# [NbConvertApp] Writing 342710 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 997876 bytes to Atividade-Pratica-3.pdf
