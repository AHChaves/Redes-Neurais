# %% [markdown]
# ## Instalando pacotes necessários

# %% [markdown]
# !apt-get update
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc --break-system-packages

# %%
# !pwd
# !ls
# Out:
# /home/arthur/Documentos/Github/Redes-Neurais/Atividade 1
# Atividade-Pratica-1.ipynb  cifar-10-batches-py
# Atividade-Pratica-1.pdf    conv_pdf.ipynb

# %% [markdown]
# ## Realizando a conversão para PDF (pode ser necessário ajustar o nome do *notebook*)

# %%
# !jupyter nbconvert --to PDF "Atividade-Pratica-1.ipynb"
# Out:
# [NbConvertApp] Converting notebook Atividade-Pratica-1.ipynb to PDF
# [NbConvertApp] Support files will be in Atividade-Pratica-1_files/
# [NbConvertApp] Making directory ./Atividade-Pratica-1_files
# [NbConvertApp] Writing 80062 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 429647 bytes to Atividade-Pratica-1.pdf
